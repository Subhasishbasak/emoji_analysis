# %% [markdown]
# ### Steps
#  - for all the available users compute a current score
#          - dump it
#  - compare for a perticular emoji to its own history
#          - compare current score vs historical score
#          - generate automated comment
#  - compare for a perticular emoji to its peers
#          - compare current score vs average peer score
#          - generate automated comment

# %% [markdown]
# #### Step 1

# %%
import os
import cv2
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/media/subhasish/Professional/emoji_project/code/notebooks'

# %%
path = '../../resource/screenshots/'
name = 'Anirban.jpeg'

file_path = os.path.join(path, name)

# %%
img = cv2.imread(file_path)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import os,sys,inspect
currentdir = os.getcwd()
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
sys.path
# Out:
# ['/media/subhasish/Professional/emoji_project/code',
#  '/home/subhasish/anaconda3/lib/python36.zip',
#  '/home/subhasish/anaconda3/lib/python3.6',
#  '/home/subhasish/anaconda3/lib/python3.6/lib-dynload',
#  '',
#  '/home/subhasish/anaconda3/lib/python3.6/site-packages',
#  '/home/subhasish/anaconda3/lib/python3.6/site-packages/IPython/extensions',
#  '/home/subhasish/.ipython']

# %%
currentdir
# Out:
# '/media/subhasish/Professional/emoji_project/code/notebooks'

# %%
directory = '../' # this made my day !!
os.chdir(directory)

# %%
from get_score import compute_score

# %%
compute_score('Rohan')
# Out:
# array([0.316, 0.251, 0.433])

# %% [markdown]
#  dumping

# %%
directory = 'notebooks/' # this made my day !!
os.chdir(directory)

# %%
os.getcwd()
# Out:
# '/media/subhasish/Professional/emoji_project/code/notebooks'

# %%
list_names = os.listdir(path)

# %%
list_names.remove('light_theme')
list_names
# Out:
# ['Anirban.jpeg',
#  'aritra.jpeg',
#  'Arka',
#  'Oishi.jpeg',
#  'Rohan',
#  'Subhasish',
#  'Trisha']

# %%
directory = '../' # this made my day !!
os.chdir(directory)

# %%
os.getcwd()
# Out:
# '/media/subhasish/Professional/emoji_project/code'

# %%
for i in list_names:
    name = i.split('.')[0] + '.pickle'
    score = compute_score(i.split('.')[0])
    with open('../lib/score/' + name, 'wb') as handle:
        pickle.dump(score, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Step 2

# %%
with open('../lib/score/Rohan.pickle', 'rb') as handle:
    Rohan = pickle.load(handle)

# %%
Rohan
# Out:
# array([0.314, 0.253, 0.433])

# %%
Rohan_current = compute_score('Oishi')

# %%
Rohan_current
# Out:
# array([0.337, 0.219, 0.444])
